# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler, StandardScaler

# %%
# df.iloc[:]

# %%
df = pd.read_csv("linear-data.csv")

minmax_scaler = MinMaxScaler()
standard_scaler = StandardScaler()
minmax_scaled = minmax_scaler.fit_transform(df)
standard_scaled = standard_scaler.fit_transform(df)

print("MinMax Scaler Output")
print(pd.DataFrame(minmax_scaled, columns= ["Time", "Marks"]))
print("\nStandard Scaler Output")
print(pd.DataFrame(standard_scaled, columns= ["Time", "Marks"]))
# Out:
# MinMax Scaler Output
#        Time     Marks
# 0  0.000000  0.000000
# 1  0.166667  0.166667
# 2  0.333333  0.333333
# 3  0.500000  0.500000
# 4  0.666667  0.666667
# 5  0.833333  0.833333
# 6  1.000000  1.000000
#
# Standard Scaler Output
#    Time  Marks
# 0  -1.5   -1.5
# 1  -1.0   -1.0
# 2  -0.5   -0.5
# 3   0.0    0.0
# 4   0.5    0.5
# 5   1.0    1.0
# 6   1.5    1.5
