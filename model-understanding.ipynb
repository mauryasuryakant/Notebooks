# %% [markdown]
# # Understanding Models

# %%
from sklearn.linear_model import LinearRegression
import numpy as np
import pandas as pd

# %% [markdown]
# # Regression
# ## Linear Regression
# - Used to draw a straight line between 2 points (Predictiong numbers)
# - Supervised machine learning model
#
# ## Classification
# ### Either true or false
# - Logistic Regression (gives between 0 and 1)
# - K-Nearest Neighbors (KNN)
# - Decision Tree Classifier (It works in flowchart format)
#
# ## Model Training
# - .fit()
# - .predict()

# %%
df = pd.read_csv("data.csv")

print(df.iloc[:, 0].to_numpy())
# Out:
# ['Ayush' 'Joy' 'Prem' 'Abhay' 'Piyush' 'Zaid']
